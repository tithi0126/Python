# %%
import numpy as np
import pandas as pd

# %%
# df=pd.read_csv('Salary_Data.csv')
# df.head()
df=pd.read_csv('house.csv')
df.head()
# Out:
#    square_footage  bedrooms  bathrooms   price
# 0            2100         3          2  500000
# 1            1600         2          1  320000
# 2            2400         4          3  560000
# 3            1400         2          1  310000
# 4            3000         4          3  750000

# %%
# y=df['Salary'].values
# y
y=df['price']
y
# Out:
# 0       500000
# 1       320000
# 2       560000
# 3       310000
# 4       750000
#         ...
# 107    2100000
# 108    2130000
# 109    2150000
# 110    2180000
# 111    2200000
# Name: price, Length: 112, dtype: int64

# %%
# x=df['YearsExperience'].values
# x
x=df[['square_footage','bedrooms','bathrooms']]
x
# Out:
#      square_footage  bedrooms  bathrooms
# 0              2100         3          2
# 1              1600         2          1
# 2              2400         4          3
# 3              1400         2          1
# 4              3000         4          3
# ..              ...       ...        ...
# 107           14200         5          4
# 108           14400         5          4
# 109           14600         5          4
# 110           14800         5          4
# 111           15000         5          4
#
# [112 rows x 3 columns]

# %%
# y=y.reshape(len(y),1)
# x=x.reshape(len(x),1)
# x
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y, test_size=0.2, random_state=10)
xtest
# Out:
#      square_footage  bedrooms  bathrooms
# 103           13400         5          4
# 91            11000         5          4
# 75             7800         5          4
# 48             2400         4          3
# 53             3400         5          4
# 52             3200         4          3
# 38             1500         2          1
# 42             2900         4          3
# 2              2400         4          3
# 39             1600         2          2
# 45             3100         4          3
# 76             8000         5          4
# 90            10800         5          4
# 81             9000         5          4
# 1              1600         2          1
# 10             2600         3          2
# 37             1700         2          1
# 47             2200         3          2
# 79             8600         5          4
# 41             3000         4          3
# 35             1900         3          2
# 19             2000         3          2
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
ypred=model.predict(xtest)

# %%
ypred
# Out:
# array([1998838.42609919, 1703531.40082666, 1309788.70046327,
#         586138.22392695,  768392.48746362,  684573.8990178 ,
#         356978.75010353,  647660.52085873,  586138.22392695,
#         357695.54061364,  672269.43963144, 1334397.61923599,
#        1678922.48205395, 1457442.21309954,  369283.20948988,
#         551537.47302655,  381587.66887624,  502319.63548113,
#        1408224.37555412,  659964.98024509,  465406.25732206,
#         477710.71670842,  635356.06147238])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(xtrain,ytrain,color='red', label="Actual Data")
plt.scatter(xtrain,model.predict(xtrain),color='blue', label="Predicted Data")
plt.plot(xtrain,model.predict(xtrain),'--',color='green', label="Regression Line")
plt.legend(loc="best")
plt.show()

# %%
plt.scatter(xtest,ytest,color='red', label="Actual Data")
plt.scatter(xtest,model.predict(xtest),color='blue', label="Predicted Data")
plt.plot(xtest,model.predict(xtest),'--',color='green', label="Regression Line")
plt.legend(loc="best")
plt.show()

# %%
n=float(input("Enter Years of Experience:"))
spred=model.predict([[n]])
spred
# Out:
# Enter Years of Experience: 5.5
# array([[77551.84309688]])

# %%
# y=mx+c
m=model.coef_
c=model.intercept_
ynew=(m*n)+c
ynew
# Out:
# array([[77551.84309688]])
