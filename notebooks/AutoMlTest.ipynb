# %%
import pandas as pd 
from arti import AutoML

# Load data
df = pd.read_csv('../datasets/heart.csv')

# Create and run AutoML
ml = AutoML(
    df=df,
    target_col='age',
    test_size=0.2,
    problem_type='auto'  # Automatically detects classification/regression
)

# Run full analysis
# ml.run_complete_analysis()

# Get best model info
print(f"\nBest Model: {ml.best_model_name}")
print(f"Best Score: {ml.results[ml.best_model_name]}")

# Make predictions on new data if needed
predictions = ml.predict_new(new_data)
# Out:
# ================================================================================
# 🤖 AutoML Initialized
# ================================================================================
# 📊 Dataset: 303 rows × 14 columns
# 🎯 Target: age
# 📈 Problem Type: REGRESSION
# 🧪 Test Size: 20.0%
# ================================================================================
#
# Best Model: None
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 20
#      15 # Run full analysis
#      16 # ml.run_complete_analysis()
#      17
#      18 # Get best model info
#      19 print(f"\nBest Model: {ml.best_model_name}")
# ---> 20 print(f"Best Score: {ml.results[ml.best_model_name]}")
#      22 # Make predictions on new data if needed
#      23 predictions = ml.predict_new(new_data)
#
# KeyError: None
